# %%
import pandas as pd
import pm4py

# %%
application_event_log = pm4py.read_xes('../data/application_data.xes')
offer_event_log = pm4py.read_xes('../data/offer_data.xes')
# Out:
# ...
# parsing log, completed traces :: 100%|██████████| 42995/42995 [00:05<00:00, 7401.56it/s]

# %%
pm4py.get_end_activities(application_event_log)
# Out:
# {'W_Validate application': 12662,
#  'O_Cancelled': 4436,
#  'W_Call after offers': 9457,
#  'W_Call incomplete files': 4676,
#  'W_Complete application': 144,
#  'W_Assess potential fraud': 102,
#  'W_Personal Loan collection': 2,
#  'W_Shortened completion ': 5,
#  'A_Denied': 1,
#  'O_Sent (online only)': 8,
#  'O_Sent (mail and online)': 15,
#  'O_Returned': 1}

# %%
pm4py.get_end_activities(offer_event_log)
# Out:
# {'O_Cancelled': 20898,
#  'O_Accepted': 17228,
#  'O_Refused': 4695,
#  'O_Returned': 49,
#  'O_Sent (mail and online)': 108,
#  'O_Sent (online only)': 17}

# %%
df_offer = pm4py.convert_to_dataframe(offer_event_log)
df_offer['concept:name'].value_counts()
# Out:
# O_Create Offer              42995
# O_Created                   42995
# O_Sent (mail and online)    39707
# O_Returned                  23305
# O_Cancelled                 20898
# O_Accepted                  17228
# O_Refused                    4695
# O_Sent (online only)         2026
# Name: concept:name, dtype: int64

# %%
df_application = pm4py.convert_to_dataframe(application_event_log)
# Out:
#               Action org:resource            concept:name  EventOrigin  \
# 0            Created       User_1    A_Create Application  Application
# 1        statechange       User_1             A_Submitted  Application
# 2            Created       User_1          W_Handle leads     Workflow
# 3            Deleted       User_1          W_Handle leads     Workflow
# 4            Created       User_1  W_Complete application     Workflow
# ...              ...          ...                     ...          ...
# 1202262      Deleted       User_1     W_Call after offers     Workflow
# 1202263      Created       User_1     W_Call after offers     Workflow
# 1202264  statechange      User_28             A_Cancelled  Application
# 1202265  statechange      User_28             O_Cancelled        Offer
# 1202266      Deleted      User_28     W_Call after offers     Workflow
#
#                        EventID lifecycle:transition  \
# 0        Application_652823628             complete
# ...

# %%
df_application.groupby(['case:concept:name', 'concept:name']).size().unstack().reset_index().columns
# Out:
# Index(['case:concept:name', 'A_Accepted', 'A_Cancelled', 'A_Complete',
#        'A_Concept', 'A_Create Application', 'A_Denied', 'A_Incomplete',
#        'A_Pending', 'A_Submitted', 'A_Validating', 'O_Accepted', 'O_Cancelled',
#        'O_Create Offer', 'O_Created', 'O_Refused', 'O_Returned',
#        'O_Sent (mail and online)', 'O_Sent (online only)',
#        'W_Assess potential fraud', 'W_Call after offers',
#        'W_Call incomplete files', 'W_Complete application', 'W_Handle leads',
#        'W_Personal Loan collection', 'W_Shortened completion ',
#        'W_Validate application'],
#       dtype='object', name='concept:name')

# %%
df_offer.groupby(['case:concept:name', 'concept:name']).size().unstack().reset_index().columns
# Out:
# Index(['case:concept:name', 'O_Accepted', 'O_Cancelled', 'O_Create Offer',
#        'O_Created', 'O_Refused', 'O_Returned', 'O_Sent (mail and online)',
#        'O_Sent (online only)'],
#       dtype='object', name='concept:name')

# %%
# from https://pm4py.fit.fraunhofer.de/documentation#item-7-0-1 
from pm4py.algo.transformation.log_to_features import algorithm as log_to_features

data, feature_names = log_to_features.apply(event_log)
df = pd.DataFrame(data, columns=feature_names)
df
# Out:
#        trace:ApplicationType@Limit raise  trace:ApplicationType@New credit  \
# 0                                      0                                 1
# 1                                      0                                 1
# 2                                      0                                 1
# 3                                      0                                 1
# 4                                      0                                 1
# ...                                  ...                               ...
# 31504                                  0                                 1
# 31505                                  0                                 1
# 31506                                  0                                 1
# 31507                                  0                                 1
# 31508                                  0                                 1
#
#        event:case:ApplicationType@Limit raise  \
# ...
